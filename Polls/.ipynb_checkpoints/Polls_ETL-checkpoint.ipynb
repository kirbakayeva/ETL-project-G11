# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import numpy as np

# %%
csv_file = os.path.join( "Resources", "president_polls.csv")
polls_data_df = pd.read_csv(csv_file)
polls_data_df.head()
# Out:
#    question_id  poll_id  cycle           state  pollster_id  \
# 0       134285    71678   2020    Pennsylvania          383
# 1       134285    71678   2020    Pennsylvania          383
# 2       134286    71679   2020        Michigan          383
# 3       134286    71679   2020        Michigan          383
# 4       134249    71662   2020  North Carolina          399
#
#                                    pollster sponsor_ids  \
# 0                     Public Policy Polling        1484
# 1                     Public Policy Polling        1484
# 2                     Public Policy Polling        1484
# 3                     Public Policy Polling        1484
# 4  Rasmussen Reports/Pulse Opinion Research         NaN
#
#                        sponsors                              display_name  \
# 0  American Bridge 21st Century                     Public Policy Polling
# 1  American Bridge 21st Century                     Public Policy Polling
# 2  American Bridge 21st Century                     Public Policy Polling
# 3  American Bridge 21st Century                     Public Policy Polling
# 4                           NaN  Rasmussen Reports/Pulse Opinion Research
#
#    pollster_rating_id  ...        created_at notes  \
# 0               263.0  ...  10/22/2020 15:33   NaN
# 1               263.0  ...  10/22/2020 15:33   NaN
# 2               263.0  ...  10/22/2020 15:33   NaN
# 3               263.0  ...  10/22/2020 15:33   NaN
# 4               277.0  ...  10/22/2020 10:27   NaN
#
#                                                  url    stage race_id answer  \
# 0  https://americanbridgepac.org/wp-content/uploa...  general    6249  Biden
# 1  https://americanbridgepac.org/wp-content/uploa...  general    6249  Trump
# 2  https://americanbridgepac.org/wp-content/uploa...  general    6233  Biden
# 3  https://americanbridgepac.org/wp-content/uploa...  general    6233  Trump
# 4  https://www.rasmussenreports.com/public_conten...  general    6238  Biden
#
#   candidate_id       candidate_name  candidate_party   pct
# 0        13256  Joseph R. Biden Jr.              DEM  51.0
# 1        13254         Donald Trump              REP  46.0
# 2        13256  Joseph R. Biden Jr.              DEM  50.0
# 3        13254         Donald Trump              REP  43.0
# 4        13256  Joseph R. Biden Jr.              DEM  48.0
#
# [5 rows x 38 columns]

# %%
new_polls_data_df = polls_data_df[[ 'state', 'pollster_id', 'pollster', 'fte_grade', 'sample_size', 'population', 'methodology', 'end_date', 'nationwide_batch', 'answer', 'candidate_party', 'pct' ]].copy()
new_polls_data_df.head()
# Out:
#             state  pollster_id                                  pollster  \
# 0    Pennsylvania          383                     Public Policy Polling
# 1    Pennsylvania          383                     Public Policy Polling
# 2        Michigan          383                     Public Policy Polling
# 3        Michigan          383                     Public Policy Polling
# 4  North Carolina          399  Rasmussen Reports/Pulse Opinion Research
#
#   fte_grade  sample_size population methodology    end_date  nationwide_batch  \
# 0         B        890.0          v    IVR/Text  10/22/2020             False
# 1         B        890.0          v    IVR/Text  10/22/2020             False
# 2         B        804.0          v    IVR/Text  10/22/2020             False
# 3         B        804.0          v    IVR/Text  10/22/2020             False
# 4        C+        800.0         lv  IVR/Online  10/21/2020             False
#
#   answer candidate_party   pct
# 0  Biden             DEM  51.0
# 1  Trump             REP  46.0
# 2  Biden             DEM  50.0
# 3  Trump             REP  43.0
# 4  Biden             DEM  48.0

# %%
only_trump_and_biden = new_polls_data_df[(new_polls_data_df["answer"] == "Trump") | (new_polls_data_df["answer"] == "Biden")]
only_trump_and_biden["answer"].value_counts()
# Out:
# Trump    5939
# Biden    4426
# Name: answer, dtype: int64

# %% [markdown]
# # Which colums have null data?

# %%
only_trump_and_biden.isnull().any()
# Out:
# state                True
# pollster_id         False
# pollster            False
# fte_grade            True
# sample_size          True
# population          False
# methodology          True
# end_date            False
# nationwide_batch    False
# answer              False
# candidate_party     False
# pct                 False
# dtype: bool

# %% [markdown]
# **Columns with null values: state, fte_grade, sample_size, and methodology**

# %%
only_trump_and_biden.count()
# Out:
# state                6761
# pollster_id         10365
# pollster            10365
# fte_grade            9716
# sample_size         10363
# population          10365
# methodology         10341
# end_date            10365
# nationwide_batch    10365
# answer              10365
# candidate_party     10365
# pct                 10365
# dtype: int64

# %%
only_trump_and_biden.isnull().any(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12804    False
# 12805    False
# 12807    False
# 12809    False
# 12811     True
# Length: 10365, dtype: bool

# %%
only_trump_and_biden[only_trump_and_biden.isnull().any(axis=1)]
# Out:
#       state  pollster_id                                  pollster fte_grade  \
# 8       NaN         1193                              SurveyMonkey        D-
# 9       NaN         1193                              SurveyMonkey        D-
# 10      NaN         1193                              SurveyMonkey        D-
# 11      NaN         1193                              SurveyMonkey        D-
# 12      NaN          228                                  IBD/TIPP       A/B
# ...     ...          ...                                       ...       ...
# 12796   NaN         1416               Harris Insights & Analytics         C
# 12797   NaN         1416               Harris Insights & Analytics         C
# 12799   NaN         1416               Harris Insights & Analytics         C
# 12801   NaN         1416               Harris Insights & Analytics         C
# 12811   NaN          399  Rasmussen Reports/Pulse Opinion Research        C+
#
#        sample_size population        methodology    end_date  \
# 8          13943.0         rv             Online  10/21/2020
# 9          13943.0         rv             Online  10/21/2020
# 10         13943.0         lv             Online  10/21/2020
# 11         13943.0         lv             Online  10/21/2020
# 12           965.0         lv  Live Phone/Online  10/21/2020
# ...            ...        ...                ...         ...
# 12796       1001.0         rv             Online  12/17/2018
# 12797       1001.0         rv             Online  12/17/2018
# 12799       1001.0         rv             Online  12/17/2018
# 12801       1001.0         rv             Online  12/17/2018
# 12811       1000.0         lv         IVR/Online  11/13/2018
#
#        nationwide_batch answer candidate_party   pct
# 8                 False  Biden             DEM  52.0
# 9                 False  Trump             REP  45.0
# 10                False  Biden             DEM  52.0
# 11                False  Trump             REP  46.0
# 12                False  Biden             DEM  49.6
# ...                 ...    ...             ...   ...
# 12796             False  Biden             DEM  42.0
# 12797             False  Trump             REP  36.0
# 12799             False  Trump             REP  37.0
# 12801             False  Trump             REP  37.0
# 12811             False  Trump             REP  43.0
#
# [4005 rows x 12 columns]

# %% [markdown]
# **There are 4,005 rows out of 10,365 rows with null data. Since we are interested in state polling data in relations to our financial data by state, we will drop all rows that contain null values in state column.**

# %%
only_trump_and_biden = only_trump_and_biden.dropna(axis=0 , how='any', subset = ['state'])

# %%
only_trump_and_biden.isnull().any()
# Out:
# state               False
# pollster_id         False
# pollster            False
# fte_grade            True
# sample_size         False
# population          False
# methodology          True
# end_date            False
# nationwide_batch    False
# answer              False
# candidate_party     False
# pct                 False
# dtype: bool

# %%
only_trump_and_biden.count()
# Out:
# state               6761
# pollster_id         6761
# pollster            6761
# fte_grade           6379
# sample_size         6761
# population          6761
# methodology         6740
# end_date            6761
# nationwide_batch    6761
# answer              6761
# candidate_party     6761
# pct                 6761
# dtype: int64

# %% [markdown]
# **Above, we see now that the State column is "False" for containing any nulls. We now have 6,761 rows with State data for the candidates (Trump/Biden)**

# %% [markdown]
# # Add a new column called committee_id for Trump and Biden

# %%
only_trump_and_biden['committee_id']=''
only_trump_and_biden.head()
# Out:
#             state  pollster_id                                  pollster  \
# 0    Pennsylvania          383                     Public Policy Polling
# 1    Pennsylvania          383                     Public Policy Polling
# 2        Michigan          383                     Public Policy Polling
# 3        Michigan          383                     Public Policy Polling
# 4  North Carolina          399  Rasmussen Reports/Pulse Opinion Research
#
#   fte_grade  sample_size population methodology    end_date  nationwide_batch  \
# 0         B        890.0          v    IVR/Text  10/22/2020             False
# 1         B        890.0          v    IVR/Text  10/22/2020             False
# 2         B        804.0          v    IVR/Text  10/22/2020             False
# 3         B        804.0          v    IVR/Text  10/22/2020             False
# 4        C+        800.0         lv  IVR/Online  10/21/2020             False
#
#   answer candidate_party   pct committee_id
# 0  Biden             DEM  51.0
# 1  Trump             REP  46.0
# 2  Biden             DEM  50.0
# 3  Trump             REP  43.0
# 4  Biden             DEM  48.0

# %%
only_trump_and_biden.loc[only_trump_and_biden['answer'] == 'Trump', 'committee_id'] = "C00580100"
only_trump_and_biden.loc[only_trump_and_biden['answer'] == 'Biden', 'committee_id'] = "C00703975"
only_trump_and_biden.head()
# Out:
#             state  pollster_id                                  pollster  \
# 0    Pennsylvania          383                     Public Policy Polling
# 1    Pennsylvania          383                     Public Policy Polling
# 2        Michigan          383                     Public Policy Polling
# 3        Michigan          383                     Public Policy Polling
# 4  North Carolina          399  Rasmussen Reports/Pulse Opinion Research
#
#   fte_grade  sample_size population methodology    end_date  nationwide_batch  \
# 0         B        890.0          v    IVR/Text  10/22/2020             False
# 1         B        890.0          v    IVR/Text  10/22/2020             False
# 2         B        804.0          v    IVR/Text  10/22/2020             False
# 3         B        804.0          v    IVR/Text  10/22/2020             False
# 4        C+        800.0         lv  IVR/Online  10/21/2020             False
#
#   answer candidate_party   pct committee_id
# 0  Biden             DEM  51.0    C00703975
# 1  Trump             REP  46.0    C00580100
# 2  Biden             DEM  50.0    C00703975
# 3  Trump             REP  43.0    C00580100
# 4  Biden             DEM  48.0    C00703975

# %% [markdown]
# # Evaluate what type of values for states are present?

# %%
only_trump_and_biden['state'].value_counts()
# Out:
# Wisconsin         672
# Michigan          390
# Pennsylvania      386
# North Carolina    369
# Florida           322
# Arizona           306
# Texas             302
# Georgia           203
# Iowa              179
# California        176
# Maine             173
# Ohio              163
# New Hampshire     146
# Virginia          135
# Minnesota         130
# South Carolina    119
# Nevada            113
# Colorado          113
# Montana            99
# Missouri           96
# Utah               95
# New Jersey         94
# Kentucky           89
# Kansas             84
# Washington         84
# North Dakota       81
# New York           79
# Alaska             78
# Alabama            77
# Connecticut        77
# Maryland           75
# Oklahoma           73
# Massachusetts      72
# New Mexico         71
# Nebraska           70
# Mississippi        67
# Tennessee          66
# Delaware           66
# Indiana            66
# Louisiana          64
# West Virginia      63
# Arkansas           60
# Oregon             60
# Hawaii             60
# Vermont            58
# Illinois           58
# Idaho              58
# Washington DC      56
# Rhode Island       56
# South Dakota       56
# Wyoming            56
# Name: state, dtype: int64

# %%
output_file = os.path.join("Output", "polls_clean_df.csv")

only_trump_and_biden.to_csv(output_file, index=False, header=True)

# %% [markdown]
# # Connect to local database

# %%
pg_user = 'postgres'
pg_password = 'postgres'
db_name = 'POTUS_db'

connection_string = f"{pg_user}:{pg_password}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['States', 'Candidates', 'Candidate_Spending', 'Polls']

# %%
only_trump_and_biden.to_sql(name="Polls", con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from "Polls"', con=engine).head(50)
# Out:
#              state  pollster_id                                  pollster  \
# 0     Pennsylvania          383                     Public Policy Polling
# 1     Pennsylvania          383                     Public Policy Polling
# 2         Michigan          383                     Public Policy Polling
# 3         Michigan          383                     Public Policy Polling
# 4   North Carolina          399  Rasmussen Reports/Pulse Opinion Research
# 5   North Carolina          399  Rasmussen Reports/Pulse Opinion Research
# 6             Iowa         1102                           Emerson College
# 7             Iowa         1102                           Emerson College
# 8     Pennsylvania         1447                                    Civiqs
# 9     Pennsylvania         1447                                    Civiqs
# 10            Iowa         1554                              RMG Research
# 11            Iowa         1554                              RMG Research
# 12         Arizona          744                                     Ipsos
# 13         Arizona          744                                     Ipsos
# 14         Arizona          744                                     Ipsos
# 15         Arizona          744                                     Ipsos
# 16         Wyoming         1193                              SurveyMonkey
# 17         Wyoming         1193                              SurveyMonkey
# 18         Wyoming         1193                              SurveyMonkey
# 19         Wyoming         1193                              SurveyMonkey
# 20   West Virginia         1193                              SurveyMonkey
# 21   West Virginia         1193                              SurveyMonkey
# 22   West Virginia         1193                              SurveyMonkey
# 23   West Virginia         1193                              SurveyMonkey
# 24       Wisconsin         1193                              SurveyMonkey
# 25       Wisconsin         1193                              SurveyMonkey
# 26       Wisconsin         1193                              SurveyMonkey
# 27       Wisconsin         1193                              SurveyMonkey
# 28      Washington         1193                              SurveyMonkey
# 29      Washington         1193                              SurveyMonkey
# 30      Washington         1193                              SurveyMonkey
# 31      Washington         1193                              SurveyMonkey
