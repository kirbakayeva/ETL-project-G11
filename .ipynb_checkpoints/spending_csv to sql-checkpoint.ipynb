# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import numpy as np

# %%
csv_file = os.path.join("Output_all", "candiadates_spending.csv")

spending_data_df = pd.read_csv(csv_file, index_col = "recipient_state")
spending_data_df
# Out:
#                 disbursement_date                 recipient_name committee_id  \
# recipient_state
# DC                     2020-10-14       LEGENDARY CAMPAIGNS, LLC    C00580100
# CA                     2020-10-14                         STRIPE    C00580100
# VA                     2020-10-14  WINRED TECHNICAL SERVICES LLC    C00580100
# CA                     2020-10-14                         STRIPE    C00580100
# FL                     2020-10-14     EVENT RESOURCE GROUP, INC.    C00580100
# ...                           ...                            ...          ...
# NJ                     2020-03-18                Avis Rent A Car    C00703975
# NY                     2020-02-14               American Express    C00703975
# NY                     2020-02-14               American Express    C00703975
# NY                     2020-02-14               American Express    C00703975
# NY                     2020-02-14               American Express    C00703975
#
# ...

# %%
spending_data_df.drop(["ZZ", "AA", "AP", "VI","PR", "AE"], inplace = True) 
spending_data_df
# Out:
#                 disbursement_date                 recipient_name committee_id  \
# recipient_state
# DC                     2020-10-14       LEGENDARY CAMPAIGNS, LLC    C00580100
# CA                     2020-10-14                         STRIPE    C00580100
# VA                     2020-10-14  WINRED TECHNICAL SERVICES LLC    C00580100
# CA                     2020-10-14                         STRIPE    C00580100
# FL                     2020-10-14     EVENT RESOURCE GROUP, INC.    C00580100
# ...                           ...                            ...          ...
# NJ                     2020-03-18                Avis Rent A Car    C00703975
# NY                     2020-02-14               American Express    C00703975
# NY                     2020-02-14               American Express    C00703975
# NY                     2020-02-14               American Express    C00703975
# NY                     2020-02-14               American Express    C00703975
#
# ...

# %%
spend2_df = spending_data_df.reset_index()
spend2_df
# Out:
#       recipient_state disbursement_date                 recipient_name  \
# 0                  DC        2020-10-14       LEGENDARY CAMPAIGNS, LLC
# 1                  CA        2020-10-14                         STRIPE
# 2                  VA        2020-10-14  WINRED TECHNICAL SERVICES LLC
# 3                  CA        2020-10-14                         STRIPE
# 4                  FL        2020-10-14     EVENT RESOURCE GROUP, INC.
# ...               ...               ...                            ...
# 58920              NJ        2020-03-18                Avis Rent A Car
# 58921              NY        2020-02-14               American Express
# 58922              NY        2020-02-14               American Express
# 58923              NY        2020-02-14               American Express
# 58924              NY        2020-02-14               American Express
#
#       committee_id disbursement_description  disbursement_amount
# ...

# %%
pg_user = 'postgres'
pg_password = 'Rouzbeh237*tx'
db_name = 'POTUS_db'

connection_string = f"{pg_user}:{pg_password}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['States', 'Candidates', 'Polls', 'Candidate_Spending']

# %%
spend2_df.to_sql(name="Candidate_Spending", con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from "Candidate_Spending"', con=engine).head()
# Out:
#   committee_id disbursement_date  disbursement_amount  \
# 0    C00580100        2020-10-14                80.85
# 1    C00580100        2020-10-14                 0.77
# 2    C00580100        2020-10-14            227550.23
# 3    C00580100        2020-10-14              5133.02
# 4    C00580100        2020-10-14            113207.74
#
#                   recipient_name recipient_state disbursement_description  id
# 0       LEGENDARY CAMPAIGNS, LLC              DC       ONLINE ADVERTISING   1
# 1                         STRIPE              CA            MERCHANT FEES   2
# 2  WINRED TECHNICAL SERVICES LLC              VA            MERCHANT FEES   3
# 3                         STRIPE              CA            MERCHANT FEES   4
# 4     EVENT RESOURCE GROUP, INC.              FL    AUDIO VISUAL SERVICES   5
